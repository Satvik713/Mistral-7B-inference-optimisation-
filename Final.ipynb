# %%
 # !pip -q install git+https://github.com/huggingface/transformers
# !pip -q install bitsandbytes accelerate
# all of these libraries are used for speeding up the inference process
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 30.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 75.3 MB/s eta 0:00:00

# %%
"""
1. When loading the model normally with a 16-bit quantization, I encountered a two errors- a. CPU RAM consumed error and b. GPU shoots up to 15 gbs and then it says cuda out of memory
   To tackle this problem, firstly I loaded the model in 4-bit quantization and we also used device_map = "auto"

2. We could have further sped up the inference process by using flash-attention, but currently it doesn't support T4 gpus
"""
# Out:
# '\n1. When loading the model normally with a 16-bit quantization, I encountered a two errors- a. CPU RAM consumed error and b. GPU shoots up to 15 gbs and then it says cuda out of memory\n   To tackle this problem, firstly I loaded the model in 4-bit quantization and we also used device_map = "auto"\n\n2. We could have further sped up the inference process by using flash-attention, but currently it doesn\'t support T4 gpus\n'

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import nest_asyncio
import time
import asyncio
import textwrap

# %%
nest_asyncio.apply() # this is used to allow the notebook to run multiple event loops simultaneously

# %%
quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
)
# the weights of the model are stored in 4-bit precision
# but the computations are performed using 16-bit fp precision. This reduces the gpu ram required to store the model weights

# %%
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2", quantization_config=quantization_config, device_map="auto")
# device_map param allows the transformers library to automatically distribute the model's layers across the avilable hardware to improve performance
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
""" uncomment and run this cell to include lora adaptation. After running the module with lora, the model weigths took ~2.4 gbs of gpu ram.
    And when we load the model without lora, it takes around ~6 gbs """
# from peft import LoraConfig, get_peft_model, PeftModel
# lora_config = LoraConfig(
#     r=8, # rank of the low-rank matrices introduced by LoRA 
#     lora_alpha=16, # scaling factor for the low-rank matrices 
#     target_modules=["q_proj", "v_proj"], # adapter targets query and value projection matrices
#     lora_dropout=0.05,
#     bias="none",
#     task_type="CAUSAL_LM"
# )
# model = get_peft_model(model, lora_config)
# Out:
# ' uncomment and run this cell to include lora adaptation. After running the module with lora, the model weigths took ~2.4 gbs of gpu ram.\n    And when we load the model without lora, it takes around 6 gbs '

# %%
tokenizer.pad_token = tokenizer.eos_token
# idk why is this necessary but the model doesn't give any output without this step. It might be because the tokenizer is configured to use the EOS token as the padding token
device = 'cuda'

# %%
# a basic function to show the output in a more readable format
def wrap_text(text, width=90):
    lines = text.split('\n')
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]
    wrapped_text = '\n'.join(wrapped_lines)
    return wrapped_text

# %%
async def generate(input_texts, max_length=128):
    inputs = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True).to(device)
    outputs = model.generate(**inputs, max_length=max_length, temperature=0.1, do_sample=True)
    texts = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    wrapped_texts = [wrap_text(text) for text in texts]
    for text in wrapped_texts:
        print(text)
    return wrapped_texts

# %%
# we initialize the model with a few iterations of generating text based on a seed text, this helps the model to generate accurate responses
# https://medium.com/better-ml/model-warmup-8e9681ef4d41
def warmup_model(model, tokenizer, text, num_iterations=5):
    for _ in range(num_iterations):
        inputs = tokenizer(text, return_tensors="pt", add_special_tokens=False).to(device)
        model.generate(**inputs, max_new_tokens=100)

# %%
# this function calculates the throughput of our model for a specific set of constraints
async def benchmark_model(model, tokenizer, prompts, input_tokens, output_tokens):
    inputs = tokenizer(prompts, return_tensors="pt", max_length=input_tokens, padding=True, truncation=True).to(device)

    start_time = time.time()
    outputs = model.generate(**inputs, max_length=output_tokens)
    end_time = time.time()

    total_time = end_time - start_time
    total_tokens = (input_tokens + output_tokens) * len(prompts)
    throughput = total_tokens / total_time

    print(f'Average time per inference: {total_time/len(prompts):.4f} seconds')
    print(f'Throughput: {throughput:.2f} tokens/sec')
    return throughput

# %%
async def main_concurrent(model, tokenizer, concurrency=32):
    warmup_prompt = "<s>[INST] Warm-up prompt to prepare the model. [/INST]" # seed text to warm up the model
    benchmark_prompt = "<s>[INST] Please provide a summary of the latest news. [/INST]" # we use this text to test all the functions and check the throughput on a single prompt

    warmup_model(model, tokenizer, warmup_prompt)

    print(f'Benchmarking on predefined prompt:\n{benchmark_prompt}\n')
    await benchmark_model(model, tokenizer, [benchmark_prompt]*concurrency, input_tokens=128, output_tokens=128)

    # then we ask user for prompts; number of prompts here is equal to the number of concurrent tasks that we want out model to do
    input_prompts = []
    for i in range(concurrency):
        prompt = input(f"Enter prompt {i+1}/{concurrency}: ")
        input_prompts.append(prompt)

    print('Benchmarking on user provided prompts:')
    await benchmark_model(model, tokenizer, input_prompts, input_tokens=128, output_tokens=128)

    print('Generating responses for user provided prompts:')
    await generate(input_prompts)

# %%
if __name__ == "__main__":
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main_concurrent(model, tokenizer, concurrency=32))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Benchmarking on predefined prompt:
# <s>[INST] Please provide a summary of the latest news. [/INST]
#
# Average time per inference: 0.8335 seconds
# Throughput: 307.12 tokens/sec
# Enter prompt 1/32: what is cv?
# Enter prompt 2/32: what is ml?
# Enter prompt 3/32: what is dl?
# Enter prompt 4/32: how do we make french toast?
# Enter prompt 5/32: how to make lasagna?
# Enter prompt 6/32: what is lasgana made of?
# Enter prompt 7/32: what is rl?
# Enter prompt 8/32: how to use rl in self-driving cars?
# Enter prompt 9/32: what is policy learning?
# Enter prompt 10/32: is rl tough?
# Enter prompt 11/32: what are some use cases of rl?
# Enter prompt 12/32: how can we combine rl with llms?
# Enter prompt 13/32: what are ViTs?
# Enter prompt 14/32: what is the use of ViTs?
# Enter prompt 15/32: explain me the working of ViTs?
# Enter prompt 16/32: can we use ViT in a self-driving car?
# Enter prompt 17/32: what is the difference between ViT and CV?
# Enter prompt 18/32: do you know about tinygrad?
# Enter prompt 19/32: what is the use of tinygrad?
# Enter prompt 20/32: what is cuda?
# Enter prompt 21/32: what is the difference between cuda and metal ?
# Enter prompt 22/32: is cuda better than metal?
# Enter prompt 23/32: how tinygrad converts python to cuda or metal?
# Enter prompt 24/32: what are lazy computations?
# Enter prompt 25/32: what graph is generated by tinygrad to convert python to cuda code?
# Enter prompt 26/32: what is ONNX?
# Enter prompt 27/32: can we achieve AGI with LLMs?
# Enter prompt 28/32: what is currently most hyped topic in ML community?
# Enter prompt 29/32: What is GNN?
# Enter prompt 30/32: can we use gnn in recommendation systems?
# Enter prompt 31/32: tell me use cases of gnn?
# Enter prompt 32/32: are transformers a special case of a GNN?
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Benchmarking on user provided prompts:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Average time per inference: 0.8798 seconds
# Throughput: 290.97 tokens/sec
# Generating responses for user provided prompts:
# what is cv?
#
# CV stands for Curriculum Vitae, which is a Latin term meaning "course of life." It is a
# document used to provide detailed information about an individual's education, work
# experience, skills, and other qualifications. A CV is often used when applying for jobs,
# academic positions, or research grants. It is a more detailed and comprehensive version of
# a resume, and is typically longer than one page. The purpose of a CV is to showcase an
# individual's accomplishments and qualifications in a clear and concise manner, making
# what is ml?
#
# Machine Learning (ML) is a subfield of artificial intelligence (AI) that provides systems
# the ability to automatically learn and improve from experience without being explicitly
# programmed. It focuses on the development of computer programs that can access data and
# use it to learn for themselves. The process of learning begins with observations or data,
# such as examples, direct experience, or instruction, in order to look for patterns in data
# and make better decisions in the future based on the examples that we have provided. The
# primary aim is to allow the computers to learn automatically without human
# what is dl?
#
# DL stands for "Deep Learning," which is a subset of machine learning and artificial
# intelligence (AI) that uses neural networks with multiple layers to learn and make
# decisions from data. Deep learning models can automatically learn features from large
# amounts of data, making them particularly effective for tasks such as image and speech
# recognition, natural language processing, and predictive modeling.
#
# Deep learning models are inspired by the structure and function of the human brain, with
# each layer of the network representing a different level of abstraction or feature
# extraction. The model learns
# how do we make french toast? 1. In a shallow dish, whisk together 1 cup milk, 1/2 cup
# heavy cream, 4 eggs, 2 tbsp sugar, 1 tsp vanilla extract and a pinch of cinnamon. 2. Heat
# a non-stick skillet or griddle over medium heat. 3. Dip each slice of bread into the egg
# mixture, allowing it to soak for about 1 minute on each side. 4. Place the soaked bread
# slices onto the heated skillet or griddle and
# how to make lasagna? 1. Preheat oven to 375°F (190°C).
# 2. Cook lasagna noodles according to package instructions. Drain and rinse with cold
# water.
# 3. In a large bowl, mix together ricotta cheese, eggs, garlic, and parsley.
# 4. Spread a thin layer of tomato sauce in the bottom of a 9x13 inch baking dish.
# 5. Place a layer of cooked lasagna noodles on top of the sauce.
# what is lasgana made of?
#
# Lasagna is a traditional Italian dish made of flat pasta sheets called lasagna, which are
# usually cooked and then layered with various ingredients. The most common ingredients used
# in lasagna are:
#
# 1. Lasagna noodles: These are the flat pasta sheets that form the base of the lasagna.
# They are usually cooked before being layered with the other ingredients.
# 2. Tomato sauce: This is the base sauce that covers the bottom layer of the lasagna and is
# used to separate the layers of pasta
# what is rl?
#
# RL stands for Reinforcement Learning, which is a type of machine learning (ML) algorithm
# that allows an agent to learn how to perform a task by interacting with its environment.
# The agent learns to take actions that maximize a reward signal, which is a numerical value
# that represents the desirability of a particular state or action.
#
# In RL, the agent learns a policy, which is a mapping from states to actions, that
# maximizes the expected cumulative reward over time. The agent learns this policy through
# trial
# how to use rl in self-driving cars?
#
# To use Reinforcement Learning (RL) in self-driving cars, you would need to follow these
# general steps:
#
# 1. Define the state space: The state space represents the information that the car uses to
# make decisions. It could include variables such as the car's position, velocity, steering
# angle, and sensor data (e.g., lidar, radar, camera).
# 2. Define the action space: The action space represents the possible actions that the car
# can take based on its current state. It could include
# what is policy learning?
#
# Policy learning refers to the process by which an agent, such as an artificial
# intelligence (AI) system or a human, improves its behavior based on past experiences and
# feedback. In the context of reinforcement learning, a policy is a mapping from states to
# actions that specifies the agent's behavior. Policy learning involves finding the optimal
# policy that maximizes the expected reward over a sequence of actions. This can be achieved
# through various methods, such as value iteration, policy iteration, or deep learning
# algorithms like Q-learning and deep Q-learning.
# is rl tough?
#
# Yes, reinforcement learning (RL) can be challenging to implement and master, especially
# for complex problems. RL involves training an agent to learn how to take actions in an
# environment to maximize a reward signal. This requires a good understanding of the
# underlying mathematics and algorithms, as well as the ability to design and implement an
# effective learning environment.
#
# Moreover, RL can be computationally expensive, requiring significant computational
# resources and time to train an agent to perform well. Additionally, RL algorithms can be
# sensitive to hyperparameters and
# what are some use cases of rl?
#
# 1. Recommender Systems: RL can be used to build recommender systems that suggest items to
# users based on their past preferences and interactions.
# 2. Autonomous Driving: RL can be used to train self-driving cars to make decisions based
# on real-time sensor data and learn from experience.
# 3. Robotics: RL can be used to train robots to perform complex tasks in various
# environments, such as grasping objects, navigating mazes, or assembling products.
# 4
# how can we combine rl with llms?
#
# There are several ways to combine reinforcement learning (RL) with large language models
# (LLMs). Here are some common approaches:
#
# 1. Using LLMs as a feature extractor: In this approach, an LLM is used to extract features
# from raw text data, which are then used as inputs to an RL algorithm. The LLM can be used
# to extract semantic features, such as named entities, sentiment, or topic, from text data.
# These features can be used to train an RL agent to learn a policy that
# what are ViTs?
#
# ViTs (Visual Transformers) are a type of deep learning model for computer vision tasks,
# specifically image classification. They are based on the Transformer architecture, which
# was originally designed for natural language processing tasks. ViTs replace the
# traditional convolutional neural network (CNN) architecture with a Transformer-based
# architecture, allowing for the direct processing of image pixels as input. This approach
# enables ViTs to capture long-range dependencies and hierarchical representations in
# images, leading to state-of-the-art performance on
# what is the use of ViTs?
#
# ViTs ( Vision Transformers) are a type of deep learning model that have been designed
# specifically for image recognition tasks. They are based on the Transformer architecture,
# which was originally developed for natural language processing tasks.
#
# ViTs use self-attention mechanisms to process local and global dependencies in an image,
# allowing them to capture long-range dependencies and contextual information in a more
# effective way than traditional convolutional neural networks (CNNs). This makes them
# particularly well-suited for large-scale image recognition tasks
# explain me the working of ViTs?
#
# ViTs (Vision Transformers) are a type of deep learning model that uses Transformer
# architecture for processing visual data, such as images. Transformers were initially
# designed for natural language processing tasks, but they have since been adapted for
# computer vision tasks as well.
#
# The basic idea behind ViTs is to treat an image as a sequence of patches and apply
# Transformer-based models to learn the relationships between these patches. Here's a high-
# level overview of how ViTs work:
#
# 1. Image
# can we use ViT in a self-driving car?
#
# Yes, Vision Transformer (ViT) models can be used in self-driving cars for object detection
# and recognition tasks. ViT models are a type of transformer model that can process raw
# image data without the need for hand-crafted features or convolutional neural networks
# (CNNs). This makes them computationally efficient and well-suited for real-time
# applications like self-driving cars.
#
# However, it's important to note that using ViT models in self-driving cars requires a
# large amount
# what is the difference between ViT and CV?
#
# ViT ( Vision Transformer) and CV (Convolutional Neural Networks) are two different types
# of deep learning models used for image recognition tasks.
#
# CV (Convolutional Neural Networks) is a traditional deep learning model that uses
# convolutional layers to extract features from images. These layers apply filters to the
# input image to identify patterns and extract features, which are then passed through fully
# connected layers for classification.
#
# ViT ( Vision Transformer), on the other hand, is a more recent deep learning model that
# do you know about tinygrad?
#
# TinyGrad is a lightweight, open-source library for distributed deep learning training,
# designed to be easy to use and highly scalable. It is built on top of TensorFlow and
# PyTorch, and provides a simple interface for parallelizing and distributing training
# across multiple GPUs or machines. TinyGrad is particularly well-suited for research and
# experimentation, as it allows users to quickly and easily experiment with different
# architectures, loss functions, and optimization algorithms. It also includes built-in
# support for popular deep learning frameworks
# what is the use of tinygrad?
#
# TinyGrad is a lightweight and efficient gradient computation library for deep learning
# models. It is designed to be used in embedded systems and other resource-constrained
# environments where traditional deep learning frameworks like TensorFlow or PyTorch may be
# too large or complex. TinyGrad provides basic operations for building and training deep
# neural networks, such as forward and backward propagation, and supports common activation
# functions and loss functions. It is often used for on-device machine learning and edge AI
# applications.
# what is cuda?
#
# CUDA (Compute Unified Device Architecture) is a parallel computing platform and
# application programming interface (API) model created by NVIDIA. It allows developers to
# use NVIDIA GPUs for general purpose processing, in addition to their traditional use for
# rendering graphics. CUDA enables developers to harness the power of the GPU for a wide
# range of applications, including scientific simulations, data analytics, machine learning,
# and more.
#
# The CUDA architecture is designed to provide a unified programming model for both the CPU
# and GPU,
# what is the difference between cuda and metal ?
#
# CUDA and Metal are two different parallel computing frameworks, each designed for specific
# platforms.
#
# CUDA is a parallel computing platform and programming model developed by NVIDIA. It is
# primarily used for general-purpose computing on NVIDIA GPUs. CUDA provides a C/C++
# programming interface, along with a large ecosystem of libraries and tools, to enable
# developers to write and run code on GPUs. CUDA is widely used in scientific computing,
# machine learning, and other fields where high performance and parallelism
# is cuda better than metal?
#
# Both CUDA and Metal are parallel computing frameworks designed to optimize performance for
# GPU computing. CUDA is a more established and widely used framework, developed by NVIDIA,
# while Metal is a framework developed by Apple for use on Apple devices.
#
# In terms of raw performance, CUDA has a larger user base and a more extensive set of
# libraries and tools, which can lead to better optimization and higher performance. CUDA
# also supports a wider range of GPUs, including those from NVIDIA and other vendors
# how tinygrad converts python to cuda or metal?
#
# I'm trying to understand how tinygrad converts python code to CUDA or Metal code. I've
# read the paper "TinyGrad: A Fast and Lightweight Deep Learning Framework" but I'm still
# not clear on the conversion process.
#
# From what I understand, TinyGrad uses a static analysis approach to identify the
# computation graph from the Python code. But how does it convert this graph to CUDA or
# Metal code? Is there a pre-existing library of CUDA or Metal functions that correspond
# what are lazy computations?
#
# Lazy computation is a programming technique where the result of a computation is not
# produced until it is actually needed. This is in contrast to eager computation, where the
# result of a computation is produced as soon as it is defined.
#
# In lazy computation, the computation is suspended until a value is requested from it. At
# that point, the computation is evaluated, and the resulting value is produced and
# returned. This can be useful in situations where the computation is expensive or involves
# large amounts of data, as it allows the computation to be deferred until it
# what graph is generated by tinygrad to convert python to cuda code?
#
# Tiny-Grad is a Python library for automatic differentiation and it does not generate any
# specific graph for converting Python code to CUDA code. Instead, it computes gradients
# symbolically using backpropagation and can then apply various optimization techniques to
# the resulting expressions.
#
# If you want to run your Python code on a GPU using CUDA, you would typically need to write
# CUDA code yourself or use a higher-level library such as PyTorch or TensorFlow that
# provides CUDA support. These libraries can
# what is ONNX?
#
# ONNX (Open Neural Network Exchange) is an open format for representing machine learning
# models. It is a community-driven, industry-standard format for exchanging deep learning
# models. ONNX enables models to be transferred between various machine learning frameworks,
# tools, runtimes, and compilers.
#
# ONNX provides a common format for representing models, which makes it easier to move
# models between different deep learning frameworks, such as TensorFlow, PyTorch, and
# Microsoft Cognitive Toolkit (CNTK).
# can we achieve AGI with LLMs?
#
# I believe that Large Language Models (LLMs) can be a powerful tool in the pursuit of
# Artificial General Intelligence (AGI), but they are not AGI themselves. AGI refers to a
# machine intelligence that can understand, learn, and apply knowledge across a broad range
# of tasks at a level equal to or beyond that of a human being. LLMs, on the other hand, are
# specifically designed to process and generate human-like text based on input data.
#
# However, LLMs can be used as a foundation for AGI
# what is currently most hyped topic in ML community?
#
# There are several topics that are currently generating a lot of buzz in the machine
# learning community. Here are a few of them:
#
# 1. Transformers: Transformers are a type of neural network architecture that has gained
# significant attention in recent years due to their ability to process sequences of data,
# such as text or speech, with impressive results. Transformers have been used to achieve
# state-of-the-art performance on a variety of natural language processing tasks, including
# machine translation, text summarization, and question answering.
# 2
# What is GNN?
#
# Graph Neural Networks (GNNs) are a type of neural network that can process graph data
# structures. They are designed to learn representations of nodes and edges in a graph,
# allowing them to make predictions or perform other tasks based on the graph's structure
# and node features.
#
# GNNs have gained popularity in recent years due to their ability to handle complex
# relationships between data points, such as those found in social networks, chemical
# compounds, and other real-world systems. They can be used for a variety of tasks,
# including
# can we use gnn in recommendation systems?
#
# Yes, Graph Neural Networks (GNNs) can be used in recommendation systems. Recommendation
# systems are a type of information filtering system that suggests items to users based on
# their past behavior or preferences. In a collaborative filtering approach, recommendations
# are based on the behavior or preferences of other users. In a content-based approach,
# recommendations are based on the features of the items.
#
# GNNs can be used to model the relationships between users and items in a recommendation
# system as a graph. Each node in the
# tell me use cases of gnn?
#
# A Graph Neural Network (GNN) is a type of neural network designed to process graph data,
# where nodes represent entities and edges represent relationships between them. Here are
# some common use cases of GNNs:
#
# 1. Social Network Analysis: GNNs can be used to analyze social networks, where nodes
# represent individuals and edges represent relationships between them. Applications include
# recommendation systems, community detection, and sentiment analysis.
# 2. Protein Structure Prediction: GNNs can be used to predict the three-dimensional
# structure of
# are transformers a special case of a GNN?
#
# I've been reading about transformers and graph neural networks (GNNs) and I'm wondering if
# transformers are a special case of a GNN or if they are fundamentally different.
#
# Transformers were originally designed for sequence-to-sequence tasks, such as machine
# translation, where the input and output sequences have a clear order. However, they have
# also been applied to other tasks, such as graph-level classification and graph generation,
# where the input and output graphs may not have a clear order.
#
# GNN
